# %%
import pandas as pd

# %%
df = pd.read_csv('Bollywood.csv')

# %%
df.columns
# Out:
# Index(['Movie_Name', 'Release_Period', 'Whether_Remake', 'Whether_Franchise',
#        'Genre', 'New_Actor', 'New_Director', 'New_Music_Director', 'Lead_Star',
#        'Director', 'Music_Director', 'Screens', 'Budget', 'Revenue',
#        'Profit_Factor', 'Year', 'Duration', 'Rating', 'Votes'],
#       dtype='object')

# %%
#Change column name Lead Star to Lead_Star Movie Name to Movie_Name
df.rename(columns={'Lead Star':'Lead_Star',
                    'Movie Name':'Movie', 
                    'Release Period': 'Release_Period',
                    'Whether Remake': 'Whether_Remake',
                    'Whether Franchise': 'Whether_Franchise',
                    'New Actor': 'New_Actor',
                    'New Director': 'New_Director',
                    'New Music Director': 'New_Music_Director',
                    'Music Director':'Music_Director',
                    'Number of Screens': 'Screens',
                    'Budget(INR)': 'Budget',
                    'Revenue(INR)': 'Revenue',
                    'ProfitFactor': 'ProfitFactor',
                    'Rating': 'IMDb'},inplace=True)

# df.to_csv('Bollywood.csv', index=False)

# %%
#read json file
df = pd.read_json('Bollywood.json')

# %%
#change Genre love_story to Romance and rom_com to Romance
df['Genre'] = df['Genre'].replace(['love_story', 'rom__com'], 'romance')

#change all Genre to Sentence case
df['Genre'] = df['Genre'].str.title()

# %%
#sort df by Rating
df = df.sort_values(by='Rating', ascending=False)

#remove columns Release_Period, Whether_Remake, Whether_Franchise, New_Actor, New_Director, New_Music_Director, Music_Director, Lead_Star, Music_Director
df.drop(['Release_Period', 'Whether_Remake', 'Whether_Franchise', 'New_Director', 'New_Music_Director', 'Music_Director', 'Profit_Factor'], axis=1, inplace=True)

#rename columns
df.rename(columns={'Movie_Name':'Movie', 'Lead_Star': 'Star', 'New_Actor': 'Newbie'}, inplace=True)

# %%
#top 10 movies
df1 = df

# %%
# df1.to_csv('Bollywood1.csv', index=False)
df1 = df1 = df1.sort_values(by='Year', ascending=True)
df1 = df1[df1['Newbie']=='Yes']
df1 = df1[df1['Year']>=2000]
# Out:
#                          Movie        Genre Newbie                Star  \
# 641   Hazaaron Khwaishein Aisi        Drama    Yes        Shiney Ahuja
# 918         Sau Jhooth Ek Sach        Drama    Yes           Mammootty
# 849              Ho Sakta Hai!        Drama    Yes     Victor Banerjee
# 353               Socha Na Tha      Romance    Yes          Abhay Deol
# 179                       Sins        Drama    Yes        Shiney Ahuja
# ..                         ...          ...    ...                 ...
# 84            Secret Superstar        Drama    Yes         Zaira Wasim
# 369                     Poorna        Drama    Yes       Aditi Inamdar
# 765                    Machine     Thriller    Yes  Mustafa Burmawalla
# 215  Sachin - A Billion Dreams  Documentary    Yes    Sachin Tendulkar
# 563                    Julie 2     Thriller    Yes          Raai Laxmi
#
#               Director  Screens     Budget     Revenue  Year  Duration  \
# 641      Sudhir Mishra       35   27500000     6900000  2003       120
# 918     Bappaditya Roy        3    5000000      180000  2004       110
# 849       Wilson Louis       25   12500000      800000  2004       101
# 353         Imtiaz Ali      110   50000000    52800000  2005       137
# 179        Vinod Pande       50   12500000    23800000  2005       138
# ..                 ...      ...        ...         ...   ...       ...
# 84      Advait Chandan     1750  450000000  1225350000  2017       150
# 369         Rahul Bose      300   37500000    37100000  2017       100
# 765     Abbas - Mustan     1600  300000000    34847500  2017       148
# 215      James Erskine     1950  390000000   649515000  2017       138
# 563  Deepak Shivdasani     1000   85000000    33100000  2017       159
#
#      Rating  Votes
# 641     7.9   4744
# 918     7.2     70
# 849     6.1     45
# 353     7.4   7475
# 179     4.2    387
# ..      ...    ...
# 84      7.8  21923
# 369     7.8   1343
# 765     2.7    761
# 215     8.6   7711
# 563     2.3    311
#
# [171 rows x 12 columns]
